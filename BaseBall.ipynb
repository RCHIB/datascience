# %%
import pandas as pd
import numpy as np
df_baseball=pd.read_csv(r'C:\DataSet\baseball.csv')
df_baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df_baseball.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df_baseball.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df_baseball.shape
# Out:
# (30, 17)

# %%
#checking for null values
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_baseball.isnull(),annot=True)
plt.show()

# %%
#checking for null values without visualization
df_baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#checking for data type
df_baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df_baseball.ERA = df_baseball.ERA.astype(int)

# %%
df_baseball.dtypes
# Out:
# W      int64
# R      int64
# AB     int64
# H      int64
# 2B     int64
# 3B     int64
# HR     int64
# BB     int64
# SO     int64
# SB     int64
# RA     int64
# ER     int64
# ERA    int32
# CG     int64
# SHO    int64
# SV     int64
# E      int64
# dtype: object

# %%
df_baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     int32
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: int32(1), int64(16)
# memory usage: 4.0 KB

# %%
df_baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import seaborn as sns
sns.pairplot(df_baseball)

# %%
#corelation matrix
sns.heatmap(df_baseball.corr())

# %%
sns.distplot(df_baseball['ERA'])

# %%
sns.distplot(df_baseball['W'])

# %%
#check for outlier
from scipy.stats import zscore
z_score=abs(zscore(df_baseball))
print(df_baseball.shape)
df_baseball_final=df_baseball.loc[(z_score<3).all(axis=1)]
print(df_baseball_final.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
sns.lineplot(x=df_baseball["R"],y=df_baseball["W"],data=df_baseball)
plt.show()

# %%
sns.lineplot(x=df_baseball["ER"],y=df_baseball["W"],data=df_baseball)
plt.show()

# %%
sns.lineplot(x=df_baseball["ERA"],y=df_baseball["W"],data=df_baseball)
plt.show()

# %%
plt.hist(x="W",bins=10,data=df_baseball)
plt.show()

# %%
#checking for skewness
df_baseball.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA   -0.133406
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#separatating the ip and op variable to be used for linear regression problem
x= df_baseball[['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','SHO','SV','E']]
y=df_baseball['W']

# %%
#SCALLING DOWN using standard scalar
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.86266219, -0.81462859,  1.67160651, -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.75482941,  0.1728    ,  0.24987932, -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.86266219, -0.32091429, -0.65485616, -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217, -0.86266219, -0.56777144, -0.78410408,  0.48575751],
#        [ 0.01327008,  1.28073815,  1.98408098,  0.80189192,  1.72234737,
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model

# %%
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x, y,random_state = r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("random state :",r_state," and f1 score: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        rs=r_state
print("maximum f1_score is at random state :",rs," and it is :",max_r_score)
# Out:
# random state : 42  and f1 score:  0.5338019096681071
# random state : 43  and f1 score:  -0.4293407305396424
# random state : 44  and f1 score:  0.6263941684684897
# random state : 45  and f1 score:  0.2257561546353154
# random state : 46  and f1 score:  0.2789371616276959
# random state : 47  and f1 score:  0.6933934741544974
# random state : 48  and f1 score:  0.9253291500456138
# random state : 49  and f1 score:  0.1503220547609989
# random state : 50  and f1 score:  0.61357216431087
# random state : 51  and f1 score:  -0.09359222969258552
# random state : 52  and f1 score:  -0.17636267170663733
# random state : 53  and f1 score:  0.2038464117393043
# random state : 54  and f1 score:  0.7361510559105029
# random state : 55  and f1 score:  0.6988365372919267
# random state : 56  and f1 score:  0.7155204600023948
# random state : 57  and f1 score:  -1.3950519634277692
# random state : 58  and f1 score:  0.35544893492410856
# random state : 59  and f1 score:  0.18225729154942671
# ...

# %%
#cross-val
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=3,scoring="r2").mean()
# Out:
# -3.0772133996122597

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y,random_state = 20,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("r2 score is :",r2_score(y_test,y_pred))
print("RME is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is : -0.11374834597091699
# RME is :  7.3116291349195235

# %%
from sklearn.externals import joblib
joblib.dump(lr,'baseball.pkl')
# Out:
# C:\Users\605822\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['baseball.pkl']
