# %%
#Skyserver Data Set
import pandas as pd
import numpy as np
df_Skyserver=pd.read_csv(r'C:\DataSet\Skyserver.csv')
df_Skyserver
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
df_Skyserver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# ...

# %%
# Check for Null Data
df_Skyserver.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
#check for the data types
df_Skyserver.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %%
df_Skyserver.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
df_Skyserver.tail()
# Out:
#              objid          ra        dec         u         g         r  \
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 9995  16.68305  16.50570  1345    301       3    161  5.033450e+17  GALAXY
# 9996  16.71661  16.69897  1345    301       3    162  5.033400e+17  GALAXY
# 9997  17.43302  17.42048  1345    301       3    162  8.222620e+18    STAR
# 9998  17.36284  17.13988  1345    301       3    163  5.033400e+17  GALAXY
# 9999  15.83548  15.50588  1345    301       3    163  5.033410e+17  GALAXY
#
#       redshift  plate    mjd  fiberid
# 9995  0.027583    447  51877      246
# ...

# %%
df_Skyserver.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df_Skyserver['class'].head(10)
ax = sns.countplot(x='class',data=df_Skyserver)

# %%
#changing categorical value into the int type
df_Skyserver['class']=df_Skyserver['class'].map({'STAR':0,'GALAXY':1,'QSO':2}).astype(int)

# %%
#correlation matrix
ax = plt.subplots(figsize=(10,8))
sns.heatmap(df_Skyserver.corr(), vmax=.8 ,annot=True,square=True,fmt=".2f")

# %%
#from the above heat map. it can be concluded that there are values/columns that are not required
#soo dropping the unwanted values
df_Skyserver=df_Skyserver.drop(['objid','rerun','specobjid','fiberid'],axis=1)

# %%
#now again plotting the heat map
#recall the heatmap
ax = plt.subplots(figsize=(10,8))
sns.heatmap(df_Skyserver.corr(), vmax=.8 , annot=True,square=True,fmt=".2f")

# %%
df_Skyserver.describe()
# Out:
#                  ra           dec             u             g             r  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     175.529987     14.836148     18.619355     17.371931     16.840963
# std       47.783439     25.212207      0.828656      0.945457      1.067764
# min        8.235100     -5.382632     12.988970     12.799550     12.431600
# 25%      157.370946     -0.539035     18.178035     16.815100     16.173333
# 50%      180.394514      0.404166     18.853095     17.495135     16.858770
# 75%      201.547279     35.649397     19.259232     18.010145     17.512675
# max      260.884382     68.542265     19.599900     19.918970     24.802040
#
#                   i             z           run        camcol         field  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      16.583579     16.422833    981.034800      3.648700    302.380100
# ...

# %%
#feature engineering 
#plotting relevant graph for visulaization
def dist(df0,df1,df2,label0,label1,label2,features):
    plt.figure()
    fig,ax=plt.subplots(13,1,figsize=(8,45))
    i=0
    for ft in features:
        i+=1
        plt.subplot(13,1,i)
        
        sns.distplot(df0[ft], hist=False,label=label0)
        sns.distplot(df1[ft], hist=False,label=label1)
        sns.distplot(df2[ft], hist=False,label=label2)
        plt.xlabel(ft, fontsize=11)
        
        plt.tick_params(axis='x', labelsize=9)
        plt.tick_params(axis='y', labelsize=9)
    plt.show()
t0 = df_Skyserver.loc[df_Skyserver['class'] == 0]
t1 = df_Skyserver.loc[df_Skyserver['class'] == 1]
t2 = df_Skyserver.loc[df_Skyserver['class'] == 2]
features = df_Skyserver.columns.values[:13]
dist(t0,t1,t2, 'STAR', 'GALAXY','QSO', features)
# Out:
# C:\Users\605822\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\605822\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\605822\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#from the output of the above.. taking into the consideration of redshift
df_Skyserver[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#    class  redshift
# 2      2  1.218366
# 1      1  0.080325
# 0      0  0.000043

# %%
#preparing data and modelling
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X=df_Skyserver.drop(['class'],axis=1)
y=df_Skyserver['class']

# %%
X=StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=44, shuffle =True)
X_train
# Out:
# array([[-0.93572463,  1.471357  , -1.54334162, ..., -0.22622668,
#         -0.56688806, -0.70581092],
#        [-0.15402103, -0.54648393,  1.16035207, ..., -0.36756491,
#          1.32835484,  1.73946796],
#        [-0.05468482, -0.62355222,  0.95827984, ..., -0.36984595,
#          0.79164889,  1.04526023],
#        ...,
#        [ 1.44339239, -0.60824952, -0.76218229, ..., -0.23986549,
#         -0.623354  , -0.82757853],
#        [-0.04586363,  1.98709129,  0.28679756, ..., -0.20785831,
#         -0.48302776, -0.58536687],
#        [-0.02855027, -0.64485605, -0.92987184, ..., -0.37003036,
#         -0.63341724, -0.43778983]])

# %%
#predicting using Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
random_forest = RandomForestClassifier(n_estimators=200)
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = random_forest.predict(X_test)
Test_acc_random_forest = round(random_forest.score(X_test, y_test) * 100, 3)
print("Score from the prediction : ",Test_acc_random_forest)
# Out:
# Score from the prediction :  99.05

# %%
sns.heatmap(confusion_matrix(y_test , y_pred), center=True,annot=True,fmt='.1f')
